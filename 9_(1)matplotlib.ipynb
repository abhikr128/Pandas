# %% [markdown]
# ### Matplotlib

# %%
import matplotlib as plt
import pandas as pd

# %%
cols = ['date', 'open', 'close']
apple_stock = pd.read_csv('AAPL.csv', usecols=cols, index_col='date', parse_dates=['date'])
apple_stock
# Out:
#                              close    open
# date
# 2015-05-27 00:00:00+00:00  132.045  130.34
# 2015-05-28 00:00:00+00:00  131.780  131.86
# 2015-05-29 00:00:00+00:00  130.280  131.23
# 2015-06-01 00:00:00+00:00  130.535  131.20
# 2015-06-02 00:00:00+00:00  129.960  129.86
# ...                            ...     ...
# 2020-05-18 00:00:00+00:00  314.960  313.17
# 2020-05-19 00:00:00+00:00  313.140  315.03
# 2020-05-20 00:00:00+00:00  319.230  316.68
# 2020-05-21 00:00:00+00:00  316.850  318.66
# 2020-05-22 00:00:00+00:00  318.890  315.77
#
# [1258 rows x 2 columns]

# %% [markdown]
# #### Sample plot

# %%
apple_stock.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# #### Line plots

# %%
cols = ['date', 'high', 'low', 'open', 'close']
apple_stock = pd.read_csv('AAPL.csv', usecols=cols, index_col='date', parse_dates=['date'])
apple_stock.plot()
# Out:
# <Axes: xlabel='date'>

# %%
apple_stock.loc['2016-05'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
apple_stock.loc['2016-05'].plot(y=['close', 'open'])
# Out:
# <Axes: xlabel='date'>

# %%
apple_stock.plot(subplots=True, figsize=(12, 8))
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>], dtype=object)

# %%
apple_stock.plot(title='Apple Stock', xlabel='Years', ylabel='Price', grid='True', figsize=(10, 8))
# Out:
# <Axes: title={'center': 'Apple Stock'}, xlabel='Years', ylabel='Price'>

# %%
apple_stock.loc['2016-05'].plot(y='close', c='g', linewidth=2, linestyle='-')     # use linestyle=':' for dotted line
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Bar plots

# %%
print("Thanks!")
# Out:
# Thanks!
