# %% [markdown]
# ### Hierarchical Indexing( Multi-Indexing)

# %%
import pandas as pd

# %%
pokemons = pd.read_csv('Pokemon.csv')        
pokemons
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### In Pandas, you can create multi index by passing in a slist of column names into set_index()

# %%
pokemons.set_index(['Name', 'Type 1'], inplace=True)
pokemons
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Name                  Type 1
# Bulbasaur             Grass      1  Poison    318  45      49       49
# Ivysaur               Grass      2  Poison    405  60      62       63
# Venusaur              Grass      3  Poison    525  80      82       83
# VenusaurMega Venusaur Grass      3  Poison    625  80     100      123
# Charmander            Fire       4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Diancie               Rock     719   Fairy    600  50     100      150
# DiancieMega Diancie   Rock     719   Fairy    700  50     160      110
# HoopaHoopa Confined   Psychic  720   Ghost    600  80     110       60
# HoopaHoopa Unbound    Psychic  720    Dark    680  80     160       60
# Volcanion             Fire     721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemons.index        # Returns each index as a tuple
# Out:
# MultiIndex([(                'Bulbasaur',   'Grass'),
#             (                  'Ivysaur',   'Grass'),
#             (                 'Venusaur',   'Grass'),
#             (    'VenusaurMega Venusaur',   'Grass'),
#             (               'Charmander',    'Fire'),
#             (               'Charmeleon',    'Fire'),
#             (                'Charizard',    'Fire'),
#             ('CharizardMega Charizard X',    'Fire'),
#             ('CharizardMega Charizard Y',    'Fire'),
#             (                 'Squirtle',   'Water'),
#             ...
#             (                   'Noibat',  'Flying'),
#             (                  'Noivern',  'Flying'),
#             (                  'Xerneas',   'Fairy'),
#             (                  'Yveltal',    'Dark'),
#             (         'Zygarde50% Forme',  'Dragon'),
#             (                  'Diancie',    'Rock'),
#             (      'DiancieMega Diancie',    'Rock'),
# ...

# %% [markdown]
# #### Use get_level_values() to specify which index you want to get back

# %%
pokemons.index.get_level_values(0)
# Out:
# Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X',
#        'CharizardMega Charizard Y', 'Squirtle',
#        ...
#        'Noibat', 'Noivern', 'Xerneas', 'Yveltal', 'Zygarde50% Forme',
#        'Diancie', 'DiancieMega Diancie', 'HoopaHoopa Confined',
#        'HoopaHoopa Unbound', 'Volcanion'],
#       dtype='object', name='Name', length=800)

# %%
# You can also swap the labels using swap_label
pokemons = pokemons.swaplevel()
pokemons
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Type 1  Name
# Grass   Bulbasaur                1  Poison    318  45      49       49
#         Ivysaur                  2  Poison    405  60      62       63
#         Venusaur                 3  Poison    525  80      82       83
#         VenusaurMega Venusaur    3  Poison    625  80     100      123
# Fire    Charmander               4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Rock    Diancie                719   Fairy    600  50     100      150
#         DiancieMega Diancie    719   Fairy    700  50     160      110
# Psychic HoopaHoopa Confined    720   Ghost    600  80     110       60
#         HoopaHoopa Unbound     720    Dark    680  80     160       60
# Fire    Volcanion              721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1  Name
# ...

# %%
pokemons.sort_values('Type 1')
# Out:
#                    #    Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Name
# Bug    Sewaddle  540     Grass    310   45      53       70       40       60
#        Pinsir    127       NaN    500   65     125      100       55       70
#        Burmy     412       NaN    224   40      29       45       29       45
#        Scyther   123    Flying    500   70     110       80       55       80
#        Joltik    595  Electric    319   50      47       50       57       50
# ...              ...       ...    ...  ...     ...      ...      ...      ...
# Water  Totodile  158       NaN    314   50      65       64       44       48
#        Basculin  550       NaN    460   70      92       65       80       55
#        Vaporeon  134       NaN    525  130      65       60      110       95
#        Panpour   515       NaN    316   50      53       48       53       48
#        Chinchou  170  Electric    330   75      38       38       56       56
#
# ...

# %% [markdown]
# ### Multi-Indexing(Continued)

# %%
pokemons = pd.read_csv('Pokemon.csv', index_col=['Type 1', 'Name'])
pokemons
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Type 1  Name
# Grass   Bulbasaur                1  Poison    318  45      49       49
#         Ivysaur                  2  Poison    405  60      62       63
#         Venusaur                 3  Poison    525  80      82       83
#         VenusaurMega Venusaur    3  Poison    625  80     100      123
# Fire    Charmander               4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Rock    Diancie                719   Fairy    600  50     100      150
#         DiancieMega Diancie    719   Fairy    700  50     160      110
# Psychic HoopaHoopa Confined    720   Ghost    600  80     110       60
#         HoopaHoopa Unbound     720    Dark    680  80     160       60
# Fire    Volcanion              721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1  Name
# ...

# %% [markdown]
# ##### Selecting rows

# %%
pokemons.loc['Grass']        # Now, we can select all the Grass Pokemons
# Out:
#                          #    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                1    Poison    318   45      49       49       65
# Ivysaur                  2    Poison    405   60      62       63       80
# Venusaur                 3    Poison    525   80      82       83      100
# VenusaurMega Venusaur    3    Poison    625   80     100      123      122
# Oddish                  43    Poison    320   45      50       55       75
# ...                    ...       ...    ...  ...     ...      ...      ...
# Chespin                650       NaN    313   56      61       65       48
# Quilladin              651       NaN    405   61      78       95       56
# Chesnaught             652  Fighting    530   88     107      122       74
# Skiddo                 672       NaN    350   66      65       48       62
# Gogoat                 673       NaN    531  123     100       62       97
#
#                        Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemons.loc['Grass', 'Attack']      # Selecting a column
# Out:
# Name
# Bulbasaur                 49
# Ivysaur                   62
# Venusaur                  82
# VenusaurMega Venusaur    100
# Oddish                    50
#                         ...
# Chespin                   61
# Quilladin                 78
# Chesnaught               107
# Skiddo                    65
# Gogoat                   100
# Name: Attack, Length: 70, dtype: int64

# %%
pokemons.loc[('Grass', 'Bulbasaur')]       # You can also get more specific using tuple
# Out:
# #                  1
# Type 2        Poison
# Total            318
# HP                45
# Attack            49
# Defense           49
# Sp. Atk           65
# Sp. Def           65
# Speed             45
# Generation         1
# Legendary      False
# Name: (Grass, Bulbasaur), dtype: object

# %%
pokemons.loc[('Grass', 'Bulbasaur'), 'Attack']     # Selecting a column
# Out:
# np.int64(49)

# %%
pokemons.loc[('Grass', 'Bulbasaur'), ['Attack', 'Defense']]  # Selecting multiple columns
# Out:
# Attack     49
# Defense    49
# Name: (Grass, Bulbasaur), dtype: int64

# %% [markdown]
# #### Using mutiple indices and returning all the rows require ':' at the end

# %%
pokemons.loc[(['Grass', 'Fire'], ['Bulbasaur', 'Litleo']), :]     # Using mutilple indices
# Out:
#                     #  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Name
# Grass  Bulbasaur    1  Poison    318  45      49       49       65       65
# Fire   Litleo     667  Normal    369  62      50       58       73       54
#
#                   Speed  Generation  Legendary
# Type 1 Name
# Grass  Bulbasaur     45           1      False
# Fire   Litleo        72           6      False

# %% [markdown]
# #### Ignoring certain indices

# %%
pokemons.loc[:, 'Bulbasaur', 'Legendary']    # You can use : to select all
# But you can't select a column using the syntax
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pokemons.loc[:, 'Bulbasaur', 'Legendary']    # You can use : to select all
#       2 # But you can't select a column using the syntax
#
# File c:\Users\ACER\Desktop\Pandas\jbooks2\venv\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\ACER\Desktop\Pandas\jbooks2\venv\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# ...

# %%
pokemons.loc[(:, 'Bulbasaur'), 'Legendary']  # Doesn't work
# Out:
#   Cell In[22], line 1
#     pokemons.loc[(:, 'Bulbasaur'), 'Legendary']  # Doesn't work
#                   ^
# SyntaxError: invalid syntax

# %%
pokemons.loc[(slice(None), 'Bulbasaur'), 'Legendary']    # One solution
# Out:
# Type 1  Name
# Grass   Bulbasaur    False
# Name: Legendary, dtype: bool

# %%
pokemons.loc[pd.IndexSlice[:, 'Bulbasaur'], 'Legendary']    # Another solution
# Out:
# Type 1  Name
# Grass   Bulbasaur    False
# Name: Legendary, dtype: bool
